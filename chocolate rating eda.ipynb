# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
c=pd.read_csv(r'C:\Users\Dell\Downloads\archive (15)\flavors_of_cacao.csv')
c
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
c.sample(10)
# Out:
#      Company \n(Maker-if known)     Specific Bean Origin\nor Bar Name   REF  \
# 1703  Vanleer (Barry Callebaut)                             Manhattan   963
# 730               Georgia Ramon                         Conacado Coop  1646
# 1698                   Valrhona                               Caraibe    63
# 578                    Dormouse                   Rio Caribe, Batch 7  1672
# 385                  Choco Dong      Mekong Delta, early 2014 Harvest  1696
# 823                  Holy Cacao                            San Martin   431
# 185          Beschle (Felchlin)  Indigena Amazonia, Grand Cru, Quizas   636
# 1026                      Manoa                                 Piura  1007
# 956                 L'Amourette                            Rio Caribe   833
# 598                       Durci                          Taino Secret  1630
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating  Bean\nType  \
# ...

# %%
c.columns = ["Company", "Specific Bean Origin or Bar Name", "REF", "Review Date", "Cocoa Percent", "Location", "Rating", "Bean Type", "Broad Bean Origin"]
c.sample()
# Out:
#        Company Specific Bean Origin or Bar Name   REF  Review Date  \
# 1680  Upchurch              Tanzania, Party Bar  1752         2016
#
#      Cocoa Percent Location  Rating Bean Type Broad Bean Origin
# 1680           72%   U.S.A.    3.25                    Tanzania

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company                           1795 non-null   object
#  1   Specific Bean Origin or Bar Name  1795 non-null   object
#  2   REF                               1795 non-null   int64
#  3   Review Date                       1795 non-null   int64
#  4   Cocoa Percent                     1795 non-null   object
#  5   Location                          1795 non-null   object
#  6   Rating                            1795 non-null   float64
#  7   Bean Type                         1794 non-null   object
#  8   Broad Bean Origin                 1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
c.sample()
# Out:
#         Company Specific Bean Origin or Bar Name  REF  Review Date  \
# 391  Chocola'te                        Venezuela  647         2011
#
#     Cocoa Percent Location  Rating Bean Type Broad Bean Origin
# 391           68%   U.S.A.    3.75                   Venezuela

# %%
list(c['Bean Type'][0:5])
# Out:
# ['\xa0', '\xa0', '\xa0', '\xa0', '\xa0']

# %%
c = c.applymap(lambda x: np.nan if str(x).strip()=="\xa0" else x)
c = c.applymap(lambda x: np.nan if str(x).strip()=="" else x)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company                           1795 non-null   object
#  1   Specific Bean Origin or Bar Name  1795 non-null   object
#  2   REF                               1795 non-null   int64
#  3   Review Date                       1795 non-null   int64
#  4   Cocoa Percent                     1795 non-null   object
#  5   Location                          1795 non-null   object
#  6   Rating                            1795 non-null   float64
#  7   Bean Type                         907 non-null    object
#  8   Broad Bean Origin                 1721 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
c['Bean Type'].value_counts()
# Out:
#                             887
# Trinitario                  419
# Criollo                     153
# Forastero                    87
# Forastero (Nacional)         52
# Blend                        41
# Criollo, Trinitario          39
# Forastero (Arriba)           37
# Criollo (Porcelana)          10
# Trinitario, Criollo           9
# Forastero (Parazinho)         8
# Forastero (Arriba) ASS        6
# Nacional (Arriba)             3
# Matina                        3
# EET                           3
# Beniano                       3
# Criollo (Ocumare 61)          2
# Trinitario, Forastero         2
# Trinitario (85% Criollo)      2
# Forastero (Catongo)           2
# Criollo, Forastero            2
# Amazon, ICS                   2
# Criollo (Amarru)              2
# Amazon mix                    2
# Nacional                      2
# Criollo (Ocumare)             1
# Criollo (Ocumare 67)          1
# Trinitario, TCGA              1
# Trinitario (Amelonado)        1
# ...

# %%
c['Bean Type'] = c['Bean Type'].fillna('Trinitario')

# %%
c['Bean Type'].value_counts()
# Out:
#                             887
# Trinitario                  420
# Criollo                     153
# Forastero                    87
# Forastero (Nacional)         52
# Blend                        41
# Criollo, Trinitario          39
# Forastero (Arriba)           37
# Criollo (Porcelana)          10
# Trinitario, Criollo           9
# Forastero (Parazinho)         8
# Forastero (Arriba) ASS        6
# Nacional (Arriba)             3
# Matina                        3
# EET                           3
# Beniano                       3
# Criollo (Ocumare 61)          2
# Trinitario, Forastero         2
# Trinitario (85% Criollo)      2
# Forastero (Catongo)           2
# Criollo, Forastero            2
# Amazon, ICS                   2
# Criollo (Amarru)              2
# Amazon mix                    2
# Nacional                      2
# Criollo (Ocumare)             1
# Criollo (Ocumare 67)          1
# Trinitario, TCGA              1
# Trinitario (Amelonado)        1
# ...

# %%
c.drop(['Bean Type'], axis=1, inplace=True)

# %%
c.sample()
# Out:
#                 Company Specific Bean Origin or Bar Name   REF  Review Date  \
# 395  Chocolate Con Amor                           Uganda  1760         2016
#
#     Cocoa Percent Location  Rating Broad Bean Origin
# 395           70%   U.S.A.    2.75            Uganda

# %%
c['Company'].value_counts()
# Out:
# Soma                 47
# Bonnat               27
# Fresco               26
# Pralus               25
# A. Morin             23
#                      ..
# Chocablog             1
# Marigold's Finest     1
# Chloe Chocolat        1
# Chequessett           1
# Ki' Xocolatl          1
# Name: Company, Length: 416, dtype: int64

# %%
top_companies = list(c['Company'].value_counts()[:14].index)
top_companies
# Out:
# ['Soma',
#  'Bonnat',
#  'Fresco',
#  'Pralus',
#  'A. Morin',
#  'Arete',
#  'Guittard',
#  'Domori',
#  'Valrhona',
#  'Hotel Chocolat (Coppeneur)',
#  'Mast Brothers',
#  'Coppeneur',
#  'Scharffen Berger',
#  'Zotter']

# %%
c['Company'] = c['Company'].apply(lambda x: x if x in top_companies else 'Other')
c['Company'].value_counts()
# Out:
# Other                         1471
# Soma                            47
# Bonnat                          27
# Fresco                          26
# Pralus                          25
# A. Morin                        23
# Arete                           22
# Domori                          22
# Guittard                        22
# Valrhona                        21
# Hotel Chocolat (Coppeneur)      19
# Coppeneur                       18
# Mast Brothers                   18
# Scharffen Berger                17
# Zotter                          17
# Name: Company, dtype: int64

# %%
c.drop(['Company'], axis=1, inplace=True)

# %%
c.sample()
# Out:
#     Specific Bean Origin or Bar Name   REF  Review Date Cocoa Percent  \
# 491                 Papua New Guinea  1153         2013           70%
#
#     Location  Rating Broad Bean Origin
# 491   U.S.A.     3.5  Papua New Guinea

# %%
c['Cocoa Percent'] = c['Cocoa Percent'].apply(lambda x: float(x.strip('%')) / 100.0)

# %%
c.sample(3)
# Out:
#      Specific Bean Origin or Bar Name   REF  Review Date  Cocoa Percent  \
# 1792                     Kerala State   749         2011           0.65
# 454                 Los Rios, H. Iara   558         2010           0.72
# 599          Carenero, Empyrean Sabor  1630         2015           0.70
#
#      Location  Rating Broad Bean Origin
# 1792  Austria    3.50             India
# 454   Germany    2.50           Ecuador
# 599    U.S.A.    3.25         Venezuela

# %%
c['Specific Bean Origin or Bar Name'].value_counts()
# Out:
# Madagascar                        57
# Peru                              45
# Ecuador                           42
# Dominican Republic                37
# Venezuela                         21
#                                   ..
# Conacado, #213, DR, -C             1
# Sambirano Valley, #215, MR, MC     1
# Chuao, #218, MR, MC                1
# Chuao, #217, DR, MC                1
# Brazil, Mitzi Blue                 1
# Name: Specific Bean Origin or Bar Name, Length: 1039, dtype: int64

# %%
c['Broad Bean Origin'].value_counts()
# Out:
# Venezuela                214
# Ecuador                  193
# Peru                     165
# Madagascar               145
# Dominican Republic       141
#                         ...
# Peru, Belize               1
# Peru, Mad., Dom. Rep.      1
# PNG, Vanuatu, Mad          1
# Trinidad, Ecuador          1
# Venezuela, Carribean       1
# Name: Broad Bean Origin, Length: 100, dtype: int64

# %%
c.sample(10)
# Out:
#      Specific Bean Origin or Bar Name   REF  Review Date  Cocoa Percent  \
# 1337     Caracas, Venezuela and Ghana    99         2006           0.75
# 829                          Trinidad  1038         2013           0.75
# 672                         Matagalpa  1295         2014           0.68
# 335                          Tanzania  1804         2016           0.73
# 1120                      Noir Infini    81         2006           0.99
# 1316                            Chuao   486         2010           0.75
# 560        Canoabo, Hacienda San Jose   693         2011           0.70
# 1005                           Africa   300         2008           0.75
# 307        Dominican Republic, rustic   647         2011           0.65
# 1347                        Venezuela   931         2012           0.73
#
#      Location  Rating   Broad Bean Origin
# 1337   France    3.00    Venezuela, Ghana
# 829      U.K.    3.00            Trinidad
# 672    U.S.A.    3.25           Nicaragua
# ...

# %%
c.drop(['Specific Bean Origin or Bar Name'], axis=1, inplace=True)

# %%
c.sample()
# Out:
#      REF  Review Date  Cocoa Percent   Location  Rating Broad Bean Origin
# 472  975         2012           0.75  Australia     3.5  Papua New Guinea

# %%
c['Broad Bean Origin'].value_counts()
# Out:
# Venezuela                214
# Ecuador                  193
# Peru                     165
# Madagascar               145
# Dominican Republic       141
#                         ...
# Peru, Belize               1
# Peru, Mad., Dom. Rep.      1
# PNG, Vanuatu, Mad          1
# Trinidad, Ecuador          1
# Venezuela, Carribean       1
# Name: Broad Bean Origin, Length: 100, dtype: int64

# %%
top_origin = list(c['Broad Bean Origin'].value_counts()[:14].index)
top_origin
# Out:
# ['Venezuela',
#  'Ecuador',
#  'Peru',
#  'Madagascar',
#  'Dominican Republic',
#  '\xa0',
#  'Nicaragua',
#  'Brazil',
#  'Bolivia',
#  'Belize',
#  'Papua New Guinea',
#  'Colombia',
#  'Vietnam',
#  'Costa Rica']

# %%
c['Broad Bean Origin'] = c['Broad Bean Origin'].apply(lambda x: x if x in top_origin else 'Other')

# %%
c['Broad Bean Origin'].value_counts()
# Out:
# Other                 482
# Venezuela             214
# Ecuador               193
# Peru                  165
# Madagascar            145
# Dominican Republic    141
#                        73
# Nicaragua              60
# Brazil                 58
# Bolivia                57
# Belize                 49
# Papua New Guinea       42
# Colombia               40
# Vietnam                38
# Costa Rica             38
# Name: Broad Bean Origin, dtype: int64

# %%
#feature engineering
#we can classify choclates into dark,white,normal
c[c['Cocoa Percent']<0.7].sample(10)
# Out:
#        REF  Review Date  Cocoa Percent     Location  Rating  \
# 761    259         2008           0.65       U.S.A.    3.00
# 644    105         2006           0.62  Switzerland    2.00
# 321    237         2008           0.63      Ecuador    3.50
# 987    552         2010           0.65     Colombia    3.50
# 745    355         2009           0.64        Italy    3.00
# 1490  1666         2015           0.67    Australia    3.00
# 22     797         2012           0.63       France    3.75
# 1684  1153         2013           0.64       France    3.50
# 1134   607         2010           0.67       U.S.A.    2.75
# 1139   955         2012           0.65     Colombia    2.50
#
#        Broad Bean Origin
# 761                 Peru
# 644
# 321              Ecuador
# 987             Colombia
# 745                Other
# 1490                Peru
# 22                  Peru
# 1684  Dominican Republic
# 1134             Ecuador
# 1139            Colombia

# %%
c['Chocolate Type'] = c['Cocoa Percent'].apply(lambda x: 'dark' if x>=0.7 else 'normal' if x>0.0 else 'white')

# %%
c['Chocolate Type'].value_counts()
# Out:
# dark      1467
# normal     328
# Name: Chocolate Type, dtype: int64

# %%
# Lising top 10 countries
list(c['Location'].value_counts()[:10].index)
# Out:
# ['U.S.A.',
#  'France',
#  'Canada',
#  'U.K.',
#  'Italy',
#  'Ecuador',
#  'Australia',
#  'Belgium',
#  'Switzerland',
#  'Germany']

# %%
asia = ['Japan', 'Vietnam', 'Israel', 'South Korea', 'Singapore', 'India', 'Philippines', 'Russia']
africa = ['Madagascar', 'Sao Tome', 'South Africa', 'Ghana']
north_america = ['U.S.A.', 'Canada', 'Martinique', 'Niacragua', 'Guatemala', 'St. Lucia', 'Puerto Rico', 'Mexico', 'Costa Rica', 'Honduras', 'Nicaragua', 'Domincan Republic', ]
south_america = ['Ecuador', 'Eucador', 'Colombia', 'Suriname', 'Bolivia', 'Venezuela', 'Chile', 'Peru', 'Brazil', 'Argentina', 'Lithuania']
europe = ['France', 'Denmark', 'Scotland', 'Wales', 'Czech Republic', 'Finland', 'Ireland', 'Portugal', 'Netherlands', 'Poland', 'Amsterdam', 'Sweden', 'U.K.', 'Italy', 'Belgium', 'Switzerland', 'Germany', 'Austria', 'Spain', 'Hungary', ]
oceania = ['Australia', 'New Zealand', 'Fiji']

# %%
def continents(x):
    if x in asia:
        return 'asia'
    if x in africa:
        return 'africa'
    if x in north_america:
        return 'north america'
    if x in south_america:
        return 'south america'
    if x in europe:
        return 'europe'
    if x in oceania:
        return 'oceania'
    return 'europe'

# %%
c['Continent'] = c['Location'].apply(continents)

# %%
c.sample(5)
# Out:
#        REF  Review Date  Cocoa Percent Location  Rating Broad Bean Origin  \
# 682   1387         2014           0.70   U.S.A.     3.5              Peru
# 334   1804         2016           0.75   U.S.A.     2.5         Venezuela
# 344    269         2008           0.55  Ecuador     3.5           Ecuador
# 1185  1295         2014           0.75   U.S.A.     3.0             Other
# 1236   316         2009           0.60   U.S.A.     3.0             Other
#
#      Chocolate Type      Continent
# 682            dark  north america
# 334            dark  north america
# 344          normal  south america
# 1185           dark  north america
# 1236         normal  north america

# %%
c.drop(['Location'], axis=1, inplace=True)

# %%
c.sample()
# Out:
#     Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 549            Doble & Bignall                     Panama, Raven  1371
#
#      Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 549          2014            72%              U.K.    3.25
#
#     Broad Bean\nOrigin
# 549             Panama

# %%
c['Continent'].value_counts()
# Out:
# north america    936
# europe           564
# south america    152
# oceania           70
# asia              48
# africa            25
# Name: Continent, dtype: int64

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   REF                1795 non-null   int64
#  1   Review Date        1795 non-null   int64
#  2   Cocoa Percent      1795 non-null   float64
#  3   Rating             1795 non-null   float64
#  4   Broad Bean Origin  1795 non-null   object
#  5   Chocolate Type     1795 non-null   object
#  6   Continent          1795 non-null   object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 98.3+ KB

# %%
c.drop(['REF'], axis=1, inplace=True)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review Date        1795 non-null   int64
#  1   Cocoa Percent      1795 non-null   float64
#  2   Rating             1795 non-null   float64
#  3   Broad Bean Origin  1795 non-null   object
#  4   Chocolate Type     1795 non-null   object
#  5   Continent          1795 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 84.3+ KB

# %%
c['Continent'] = pd.Categorical(c['Continent'])
c['Broad Bean Origin'] = pd.Categorical(c['Broad Bean Origin'])
c['Chocolate Type'] = pd.Categorical(c['Chocolate Type'])

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review Date        1795 non-null   int64
#  1   Cocoa Percent      1795 non-null   float64
#  2   Rating             1795 non-null   float64
#  3   Broad Bean Origin  1795 non-null   category
#  4   Chocolate Type     1795 non-null   category
#  5   Continent          1795 non-null   category
# dtypes: category(3), float64(2), int64(1)
# memory usage: 48.5 KB

# %%
# EDA #
sns.countplot(x='Chocolate Type', data=c)
# Out:
# <Axes: xlabel='Chocolate Type', ylabel='count'>

# %% [markdown]
# * We can see that a lot more dark chocolates are reviewe

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x='Cocoa Percent', y='Rating', data=c)
# Out:
# <Axes: xlabel='Cocoa Percent', ylabel='Rating'>

# %% [markdown]
# * According to this plot, we can see majority of the people do not like the extreme types of chocolate (i.e. too dark or too light). The sweet spot is around 60%-70%

# %%
sns.relplot(x="Review Date", y="Rating", size="Cocoa Percent", sizes=(15, 200), data=c);

# %% [markdown]
# * Here we can see people don't like very dark chocolates

# %%
sns.relplot(x="Review Date", y="Rating", hue="Chocolate Type", kind="line", data=c);

# %% [markdown]
# * Here we can see, the liking for dark chocolates have increased over the years whereas for the other, it's the same.

# %%
sns.countplot(x='Continent', data=c)
# Out:
# <Axes: xlabel='Continent', ylabel='count'>

# %% [markdown]
# * If we see this graph, we can make out that this dataset is not very diversed and could be biased towards the European's and the North American's likings.

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Broad Bean Origin', data=c)
# Out:
# <Axes: xlabel='Broad Bean Origin', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
sns.lineplot(y='Rating', x='Broad Bean Origin', data=c)
# Out:
# <Axes: xlabel='Broad Bean Origin', ylabel='Rating'>

# %% [markdown]
# * In this plot we can see that beans from all of the origins are more or less equally liked

# %%
cat_columns = c.select_dtypes(['category']).columns
cat_columns
# Out:
# Index(['Broad Bean Origin', 'Chocolate Type', 'Continent'], dtype='object')

# %%
c[cat_columns] = c[cat_columns].apply(lambda x: x.cat.codes)
c.sample(5)
# Out:
#       Review Date  Cocoa Percent  Rating  Broad Bean Origin  Chocolate Type  \
# 1668         2011           0.72    3.50                  7               0
# 546          2011           0.74    3.00                  5               0
# 904          2014           0.72    3.00                  0               0
# 171          2016           0.70    3.25                  1               0
# 1581         2011           0.72    3.25                  9               0
#
#       Continent
# 1668          0
# 546           3
# 904           3
# 171           3
# 1581          2

# %%
plt.figure(figsize=(10,10))
sns.heatmap(c.corr(), linewidths=0.1, vmax=1.0, square=True, cmap='coolwarm', linecolor='white', annot=True).set_title("Correlation Map")
# Out:
# Text(0.5, 1.0, 'Correlation Map')
